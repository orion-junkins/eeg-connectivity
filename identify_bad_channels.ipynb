# %%
import mne 
import os
import numpy as np
import argparse
np.random.seed(42)

expert = "expert"
id = 1
session = 1
data_in_path = f'data/raw/{expert}_{id}_{session}.set'

raw = mne.io.read_raw_eeglab(data_in_path, preload=True)
# Out:
# Reading /Users/orionjunkins/Documents/GitHub/eeg-connectivity/data/raw/expert_1_1.fdt
# /var/folders/cw/gk4vzxmx11gdm6d2k0hsdnbh0000gn/T/ipykernel_62134/2134820007.py:12: RuntimeWarning: Estimated head radius (11.6 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(data_in_path, preload=True)
# Reading 0 ... 3751518  =      0.000 ...  1831.796 secs...

# %%
raw.plot()
# Out:
# Using qt as 2D backend.
# Using pyopengl with version 3.1.6

# %%
# Print bad channels
print(raw.info['bads'])
# Out:
# ['FT10', 'FTT10h', 'FT9', 'M1']

# %%
# Plot sensors
raw.plot_sensors(show_names=True)
